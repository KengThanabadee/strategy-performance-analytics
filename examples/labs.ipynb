# %%
import pandas as pd
import numpy as np
import yfinance as yf
import matplotlib.pyplot as plt
import mplfinance as mpf

# %%
from backtest import backtest_simple

# %%
NVDA = yf.download('NVDA', period='10y', multi_level_index=False, auto_adjust=False)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
NVDA
# Out:
#              Adj Close       Close        High         Low        Open  \
# Date
# 2022-01-10   27.347021   27.400000   27.469000   25.643999   26.580999
# 2022-01-11   27.763218   27.816999   28.065001   26.839001   27.323000
# 2022-01-12   27.944868   27.999001   28.594999   27.608000   28.066999
# 2022-01-13   26.523623   26.575001   28.480000   26.497999   28.379000
# 2022-01-14   26.889914   26.941999   27.197001   26.209999   26.299999
# ...                ...         ...         ...         ...         ...
# 2026-01-02  188.850006  188.850006  192.929993  188.259995  189.839996
# 2026-01-05  188.119995  188.119995  193.630005  186.149994  191.759995
# 2026-01-06  187.240005  187.240005  192.169998  186.820007  190.520004
# 2026-01-07  189.110001  189.110001  191.369995  186.559998  188.570007
# 2026-01-08  185.039993  185.039993  189.550003  183.710007  189.110001
#
#                Volume
# Date
# 2022-01-10  594681000
# 2022-01-11  404089000
# 2022-01-12  383413000
# ...

# %%
data = macd.macd_strategy(NVDA)

# %%
bt, m = backtest.backtest_simple(data, long_or_short='long')

# %%
bt
# Out:
#                  Close        High         Low        Open     Volume  \
# Date
# 2025-01-08  140.071686  143.910632  137.522380  142.541012  227349900
# 2025-01-10  135.872849  139.881747  134.183308  137.412421  207602500
# 2025-01-13  133.193573  133.453512  129.474589  129.954469  204808900
# 2025-01-14  131.723953  136.342700  130.014430  136.012788  195590500
# 2025-01-15  136.202759  136.412693  131.254100  133.613455  185217300
# ...                ...         ...         ...         ...        ...
# 2026-01-02  188.850006  192.929993  188.259995  189.839996  148240500
# 2026-01-05  188.119995  193.630005  186.149994  191.759995  183529700
# 2026-01-06  187.240005  192.169998  186.820007  190.520004  176862600
# 2026-01-07  189.110001  191.369995  186.559998  188.570007  153224600
# 2026-01-08  185.750000  189.550003  184.660095  189.000000   44778196
#
#                 macd    signal  histogram  event  pos_raw  pos  order_count  \
# Date
# ...

# %%
import importlib

# %%
importlib.reload(plotting)
# Out:
# <module 'plotting' from 'c:\\Users\\HP\\Documents\\Python\\KengProject\\plotting.py'>

# %%
marks, flags = plotting.build_trade_marks(bt)

aps = []

aps += plotting.build_trade_addplots(bt, marks)
aps += plotting.build_indicator_addplots(bt, [plotting.macd_spec(panel=1)])

plotting.plot_candles(bt, addplots=aps)

# %%
j, k, l = plot_pack(bt)

# %%
#####

# %%
import pandas as pd
import numpy as np
